# %% [markdown]
# <a href="https://colab.research.google.com/github/yuvankrish11/DRYUVAN2031/blob/main/S47.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import matplotlib as plt

# %%
import seaborn as sns

# %%
data=pd.read_csv('Pokemon.csv')

# %%
data
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
data['Name'] = data['Name'].str.upper()
print(data)
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              BULBASAUR    Grass  Poison    318  45      49       49
# 1      2                IVYSAUR    Grass  Poison    405  60      62       63
# 2      3               VENUSAUR    Grass  Poison    525  80      82       83
# 3      3  VENUSAURMEGA VENUSAUR    Grass  Poison    625  80     100      123
# 4      4             CHARMANDER     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                DIANCIE     Rock   Fairy    600  50     100      150
# 796  719    DIANCIEMEGA DIANCIE     Rock   Fairy    700  50     160      110
# 797  720    HOOPAHOOPA CONFINED  Psychic   Ghost    600  80     110       60
# 798  720     HOOPAHOOPA UNBOUND  Psychic    Dark    680  80     160       60
# 799  721              VOLCANION     Fire   Water    600  80     110      120
#
# ...

# %%
data['Type 1'] = data['Type 1'].str.upper()
print(data)
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              BULBASAUR    GRASS  Poison    318  45      49       49
# 1      2                IVYSAUR    GRASS  Poison    405  60      62       63
# 2      3               VENUSAUR    GRASS  Poison    525  80      82       83
# 3      3  VENUSAURMEGA VENUSAUR    GRASS  Poison    625  80     100      123
# 4      4             CHARMANDER     FIRE     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                DIANCIE     ROCK   Fairy    600  50     100      150
# 796  719    DIANCIEMEGA DIANCIE     ROCK   Fairy    700  50     160      110
# 797  720    HOOPAHOOPA CONFINED  PSYCHIC   Ghost    600  80     110       60
# 798  720     HOOPAHOOPA UNBOUND  PSYCHIC    Dark    680  80     160       60
# 799  721              VOLCANION     FIRE   Water    600  80     110      120
#
# ...

# %%
data['Type 2'] = data['Type 2'].str.upper()
print(data)
# Out:
#                          #   Type 1  Type 2  Total  HP  Attack  Defense  \
# Name
# BULBASAUR                1    GRASS  POISON    318  45      49       49
# IVYSAUR                  2    GRASS  POISON    405  60      62       63
# VENUSAUR                 3    GRASS  POISON    525  80      82       83
# VENUSAURMEGA VENUSAUR    3    GRASS  POISON    625  80     100      123
# CHARMANDER               4     FIRE     NaN    309  39      52       43
# ...                    ...      ...     ...    ...  ..     ...      ...
# DIANCIE                719     ROCK   FAIRY    600  50     100      150
# DIANCIEMEGA DIANCIE    719     ROCK   FAIRY    700  50     160      110
# HOOPAHOOPA CONFINED    720  PSYCHIC   GHOST    600  80     110       60
# HOOPAHOOPA UNBOUND     720  PSYCHIC    DARK    680  80     160       60
# VOLCANION              721     FIRE   WATER    600  80     110      120
#
#                        Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Name
# ...

# %%
data.set_index('Name',inplace=True)

# %%
data.fillna('FIRE')
# Out:
#                          #   Type 1  Type 2  Total  HP  Attack  Defense  \
# Name
# BULBASAUR                1    GRASS  POISON    318  45      49       49
# IVYSAUR                  2    GRASS  POISON    405  60      62       63
# VENUSAUR                 3    GRASS  POISON    525  80      82       83
# VENUSAURMEGA VENUSAUR    3    GRASS  POISON    625  80     100      123
# CHARMANDER               4     FIRE    FIRE    309  39      52       43
# ...                    ...      ...     ...    ...  ..     ...      ...
# DIANCIE                719     ROCK   FAIRY    600  50     100      150
# DIANCIEMEGA DIANCIE    719     ROCK   FAIRY    700  50     160      110
# HOOPAHOOPA CONFINED    720  PSYCHIC   GHOST    600  80     110       60
# HOOPAHOOPA UNBOUND     720  PSYCHIC    DARK    680  80     160       60
# VOLCANION              721     FIRE   WATER    600  80     110      120
#
#                        Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Name
# ...

# %%
average_column1= data['HP'].mean()

# %%
print(average_column1)
# Out:
# 69.25875

# %%
average_column1= data['Attack'].mean()
print(average_column1)
# Out:
# 79.00125

# %%
average_column1= data['Defense'].mean()
print(average_column1)
# Out:
# 73.8425

# %%
average_column1= data['Sp. Atk'].mean()
print(average_column1)
# Out:
# 72.82

# %%
average_column1= data['Sp. Def'].mean()
print(average_column1)
# Out:
# 71.9025

# %%
average_column1= data['Speed'].mean()
print(average_column1)
# Out:
# 68.2775

# %%
fire_type_data = data[data['Type 1'] == 'Fire'].copy()
water_type_data = data[data['Type 1'] == 'Water'].copy()

# %%
fire_type_data['Type'] = 'Fire'
water_type_data['Type'] = 'Water'

# %%
combined_data = pd.concat([fire_type_data, water_type_data])

# %%
print(combined_data.head())
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  Type
# 4       60       50     65           1      False  Fire
# 5       80       65     80           1      False  Fire
# 6      109       85    100           1      False  Fire
# 7      130       85    100           1      False  Fire
# 8      159      115    100           1      False  Fire

# %%
generation_counts = data['Generation'].value_counts()

# %%
sns.lineplot(data=generation_counts)
# Out:
# <Axes: xlabel='Generation', ylabel='count'>

# %%
data['Generation'].value_counts()
# Out:
# Generation
# 1    166
# 5    165
# 3    160
# 4    121
# 2    106
# 6     82
# Name: count, dtype: int64

# %%
sns.barplot(data)
# Out:
# <Axes: >

# %%
sns.barplot(x='Defense', y='Attack').data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-e11ec908b1cd> in <cell line: 1>()
# ----> 1 sns.barplot(x='Defense', y='Attack').data
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2338         estimator = "size"
#    2339
# -> 2340     p = _CategoricalAggPlotter(
#    2341         data=data,
#    2342         variables=dict(x=x, y=y, hue=hue, units=units, weight=weights),
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in __init__(self, data, variables, order, orient, require_numeric, color, legend)
#      64     ):
#      65
# ...

# %%
sns.scatterplot(x='Defense', y='Attack')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-0622d86b4c41> in <cell line: 1>()
# ----> 1 sns.scatterplot(x='Defense', y='Attack')
#
# /usr/local/lib/python3.10/dist-packages/seaborn/relational.py in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     608 ):
#     609
# --> 610     p = _ScatterPlotter(
#     611         data=data,
#     612         variables=dict(x=x, y=y, hue=hue, size=size, style=style),
#
# /usr/local/lib/python3.10/dist-packages/seaborn/relational.py in __init__(self, data, variables, legend)
#     389         )
#     390
# --> 391         super().__init__(data=data, variables=variables)
#     392
#     393         self.legend = legend
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py in __init__(self, data, variables)
# ...

# %%
titanic_data=sns.load_dataset('titanic')

# %%
titanic_data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.barplot(y= 'survived', data=titanic_data)
# Out:
# <Axes: ylabel='survived'>

# %%
sns.boxplot(x='survived', y='age', data=titanic_data)
# Out:
# <Axes: xlabel='survived', ylabel='age'>

# %%
sns.scatterplot(x='age', y='fare', data=titanic_data)
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.boxplot(x='class', y='fare', data=titanic_data)
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
dataset = sns.load_dataset("iris")

# %%
dataset
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.scatterplot(x='petal_length', y='sepal_length', data=dataset)
# Out:
# <Axes: xlabel='petal_length', ylabel='sepal_length'>

# %%
sns.histplot(x='sepal_length', data=dataset)
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.boxplot(x='species', y='petal_length', data=dataset)
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>
